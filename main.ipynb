# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
from agent.agent import build_graph
from agent.context.spice import SPICE_CONTEXT

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatOpenAI(model="gpt-4o-mini", temperature=0)

# %%
response = build_graph()

app = response.compile()

# %%
spice_context = SPICE_CONTEXT

# %%
inputs = {
    "model": model,
    "spice_context": spice_context,
}

# %%
output = app.invoke(inputs)

# %%
output
# Out:
# {'model': ChatOpenAI(client=<openai.resources.chat.completions.completions.Completions object at 0x10d676cf0>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x10d68b4d0>, root_client=<openai.OpenAI object at 0x10d5c06e0>, root_async_client=<openai.AsyncOpenAI object at 0x10d676e40>, model_name='gpt-4o-mini', temperature=0.0, model_kwargs={}, openai_api_key=SecretStr('**********')),
#  'spice_context': '\n# About SPICE (SIT-Polytechnic Innovation Centre of Excellence)\n\n**SPICE** is a department of the **Singapore Institute of Technology (SIT)**, launched on 1 March 2022. It serves as a national innovation platform that supports companies—especially local small and medium-sized enterprises (SMEs)—in their innovation journeys, while also developing new products, services, and talent.\n\nSupported by **Enterprise Singapore**, SPICE works in collaboration with:\n- The **Centres of Innovation (COIs)** at the Polytechnics\n- The **Applied Research Centres (ARCs)** at SIT\n\nThis unique university–polytechnic partnership provides companies with access to an expanded suite of complementary expertise, technical skill sets, and facilities.\n\n## Mission and Value to Industry\n\nSPICE aims to help companies move up the innovation value chain by providing:\n\n- Access to domain experts and technical professionals\n- Access to specialized facilities and equipment, reducing upfront investment and risk\n- Access to interdisciplinary talent pools, including students and academic staff\n- Co-development of new or improved products and services\n\n## Process: How SPICE Supports Companies\n\n**Step 1:** Scope and define problem statements with companies  \n**Step 2:** Jointly ideate and conceptualize innovative solutions  \n**Step 3:** Co-create and develop new products or services  \n**Step 4:** Assess viability for scale-up and commercialization\n\n## Domain Expertise\n\nSPICE brings together a wide range of technical capabilities, including:\n\n- Artificial Intelligence\n- Augmented and Virtual Reality\n- Cybersecurity\n- Electronic, Electrical & Control Systems\n- Engineering Software\n- Food Technology\n- Internet of Things (IoT) and Industrial IoT\n- Mechanical System Design\n- Medical Systems for Therapy\n- Robotics & Autonomous Systems\n- Software Programming\n- 5G Communications\n\nThese are supported by SIT’s faculty, Professional Officers (POs) with deep industry experience, and students across multiple academic clusters.\n\n## Network for Industry Collaboration\n\nSPICE enables cross-institutional innovation by leveraging the facilities and expertise of:\n\n### At Singapore Institute of Technology\n\n- Centre for Infrastructure and Tunnel Engineering (CITE)\n- Construction Technology Innovation Laboratory (CTIL)\n- Design Factory @ SIT (DF@SIT)\n- Energy Efficiency Technology Centre (EETC)\n- FoodPlant\n- Future Communications Translation Laboratory (FCTLab)\n- Rapid Product Innovation & Development (RaPID) Centre\n\n### At Temasek Polytechnic\n\n- Aquaculture Innovation Centre (AIC)\n- Centre of Innovation for Complementary Health Product (COI-CHP)\n\nThis collaborative network accelerates the translation of research into impactful industry solutions.\n',
#  'scraped_data': {'title': 'NEA Licenses Scheme Operator To Design...',
#   'date': '31 Jul 2024',
#   'url': 'https://www.nea.gov.sg/media/news/news-releases/index/nea-licenses-scheme-operator-to-design-and-operate-the-beverage-container-return-scheme',
#   'body': 'Singapore, 31 July 2024 – The National Environment Agency (NEA) has issued a licence to Beverage Container Return Scheme Ltd. (BCRS Ltd.) on 29 July 2024 to design and operate the beverage container return scheme (“Scheme”) in Singapore. BCRS Ltd. was formed by beverage producers who had registered their interest to apply for a licence to operate the Scheme in May 2023. As the licensed operator, BCRS Ltd. will be responsible for collecting plastic and metal beverage containers for recycling on behalf of all beverage producers in Singapore for a period of seven years, from 1 April 2026 to 31 March 2033. The Scheme will be launched on 1 April 2026, instead of the earlier communicated date of 1 April 2025, at the request of the beverage producers to allow BCRS Ltd., beverage producers, and retailers more time to design and operationalise the Scheme smoothly with greater convenience for consumers.\xa0Role of the Scheme Operator 2\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 BCRS Ltd. is a not-for-profit company, newly incorporated by a consortium of beverage producers comprising Coca-Cola Singapore Beverages Pte. Ltd., F&N Foods Pte. Ltd., and Pokka Pte. Ltd. to collect, sort and recycle beverage containers. 3\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Under the Scheme, pre-packaged beverages in plastic and metal containers ranging from 150 millilitres to 3 litres will have a 10-cent refundable deposit applied to them. Consumers can identify beverage products covered under the Scheme through a deposit mark labelled on the containers. Consumers can claim a full refund of the deposit when they return empty beverage containers at designated return points, including reverse vending machines. 4\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 All producers that import or manufacture covered beverage products must participate in the Scheme. BCRS Ltd. will act on behalf of all beverage producers. As required by law, BCRS Ltd. will appoint at least two Board Directors to represent the interests of smaller beverage producers.5\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 The licence validity period is from 29 July 2024 to 31 March 2033, which takes into account approximately 20 months of preparatory period and seven years of operations from 1 April 2026 to 31 March 2033. This takes into account the depreciation period of key infrastructure such as reverse vending machines (estimated at about seven years). Leading up to the launch of the Scheme, BCRS Ltd. has to ensure that the return points are set up for consumers to return their empty beverage containers. It will oversee end-to-end management of the returned beverage containers and ensure that the fees for stakeholders involved in the Scheme will be fair, transparent and equitable. It will provide the start-up capital to initiate the Scheme operations and maintain sufficient reserves to cover the operation of the Scheme under all circumstances. BCRS Ltd. will need to maintain data protection systems to protect against data loss, unauthorised access, modification, disclosure, and misuse.6\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 NEA will work closely with BCRS Ltd. to organise outreach programmes to raise awareness among the public and industry about the Scheme, and to promote a culture of recycling. A website will be launched with information for the public and businesses, such as return point locations and educational and promotional events.Beverage Container Return Scheme will commence on 1 April 20267\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 The launch date of the Scheme has been revised from 1 April 2025 to 1 April 2026, at the request of the consortium of beverage producers. This revision is to provide sufficient time for BCRS Ltd., beverage producers, and retailers to design and operationalise the Scheme smoothly for the convenience of consumers. Since the Expression of Interest called by NEA in April 2023, the Consortium took more time than anticipated to submit a proposal that addressed its various o ...
#  'relevance': {'is_relevant': True,
#   'reason': "The article discusses the Beverage Container Return Scheme, which involves the collection and recycling of beverage containers. This aligns with SPICE's capabilities in sustainability innovation, IoT, and systems design. There is a clear opportunity for SPICE to collaborate with BCRS Ltd. in developing technology solutions for the reverse vending machines and optimizing the operational processes of the recycling scheme."},
#  'business_entity': [BusinessEntityItem(name='National Environment Agency', type='government agency', role='Issuing the licence for the beverage container return scheme'),
#   BusinessEntityItem(name='Beverage Container Return Scheme Ltd.', type='company', role='Licensed operator responsible for designing and operating the beverage container return scheme'),
#   BusinessEntityItem(name='Coca-Cola Singapore Beverages Pte. Ltd.', type='company', role='Member of the consortium of beverage producers forming BCRS Ltd.'),
#   BusinessEntityItem(name='F&N Foods Pte. Ltd.', type='company', role='Member of the consortium of beverage producers forming BCRS Ltd.'),
#   BusinessEntityItem(name='Pokka Pte. Ltd.', type='company', role='Member of the consortium of beverage producers forming BCRS Ltd.')],
#  'opportunity': 'SPICE can collaborate with BCRS Ltd. to develop and implement an integrated data management and analytics platform for the beverage container return scheme, enhancing operational efficiency and consumer engagement.',
#  'justification': "The initiative requires robust data protection systems and analytics to manage the logistics of over 1,000 return points and track recycling rates. SPICE's expertise in data analytics, IoT, and system design aligns perfectly with these needs, enabling real-time monitoring and reporting, which is crucial for the success of the scheme.",
#  '__interrupt__': [Interrupt(value='Please provide feedback:', resumable=True, ns=['wait_for_human_input:34c56a74-6186-c44e-3690-456ceb7240fc'])]}

# %%
output.get("opportunity")
# Out:
# 'SPICE can collaborate with BCRS Ltd. to develop and implement an integrated data management and analytics platform for the beverage container return scheme, enhancing operational efficiency and consumer engagement.'

# %%
output.get("justification")
# Out:
# "The initiative requires robust data protection systems and analytics to manage the logistics of over 1,000 return points and track recycling rates. SPICE's expertise in data analytics, IoT, and system design aligns perfectly with these needs, enabling the creation of a user-friendly platform that can optimize operations and improve consumer participation."
